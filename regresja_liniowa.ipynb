# %% [markdown]
# <a href="https://colab.research.google.com/github/czyz-patryk/dataScience/blob/main/regresja_liniowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

# %%
import numpy as np

X = np.arange(0, 50, 0.5)
noise = 10 * np.random.randn(100)
y = 2 * X + 100 + noise
X = X.reshape(-1, 1)

print('Rozmiar X: ', X.shape)
print('Rozmiar y: ', y.shape)
# Out:
# Rozmiar X:  (100, 1)
# Rozmiar y:  (100,)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (75, 1) (25, 1) (75,) (25,)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()

plt.figure(figsize=(7, 5))
plt.scatter(X_train, y_train, c='b', label='Zbiór treningowy')
plt.scatter(X_test, y_test, c='g', label='Zbiór testowy')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %%
from sklearn.linear_model import LinearRegression 

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [2.13734535]
# 96.79284859916089

# %%
plt.figure(figsize=(7, 5))
plt.scatter(X_train, y_train, c='b', label='Zbiór treningowy')
plt.title('Regresja Liniowa - jedna zmienna')
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %%
y_pred = lin_reg.predict(X_test)
plt.figure(figsize=(7,5))
plt.title('Regresja liniowa - jedna zmienna')
plt.scatter(X_test, y_test, c='g', label='Zbiór testowy')
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.9092078123904078

# %%
lin_reg.score?
